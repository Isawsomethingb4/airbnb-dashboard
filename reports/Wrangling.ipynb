# %%
import pandas as pd
import glob

# %%
# Creating list of dataframes
files = glob.glob('../data/raw/*.csv')
city_list = []
for f in files:
    city = pd.read_csv(f)
    if 'General' not in f:
        city['city'] = f.split('/')[-1].split('.')[0]
        city_list.append(city)

# %%
# Dropping null values
cities = pd.concat(city_list, ignore_index=True)
cities['url'] = cities['id'].apply(lambda x: f'https://www.airbnb.ca/rooms/{x}')

# %%
cities.drop(columns=['neighbourhood_group'], inplace=True)
cities.dropna(subset=['last_review', 'reviews_per_month'], inplace=True)

# %%
# Creating ratings columns
cities['rating'] = cities['name'].str.extract(r'★([\d.]+)')
# Out:
#                         id                                               name  \
# 0                     1419  Home in Toronto · ★5.0 · 5 bedrooms · 7 beds ·...
# 1                     8077  Rental unit in Toronto · ★4.84 · 1 bedroom · 1...
# 2                    26654  Condo in Toronto · ★4.79 · 1 bedroom · 2 beds ...
# 3                    27423  Rental unit in Toronto · ★4.93 · Studio · 1 be...
# 4                    30931  Rental unit in Toronto · 1 bedroom · 2 beds · ...
# ...                    ...                                                ...
# 48450  1036526981236768174  Rental unit in Fredericton · ★4.33 · 1 bedroom...
# 48454  1038950558720815520  Home in Moncton · ★New · 3 bedrooms · 3 beds ·...
# 48455  1039043653457446523  Rental unit in Fredericton · ★New · 2 bedrooms...
# 48471  1042152682470956407  Rental unit in Moncton · ★New · 1 bedroom · 2 ...
# 48484  1047108429010491595  Home in Moncton · ★New · 2 bedrooms · 2 beds ·...
#
#          host_id       host_name                      neighbourhood  \
# 0           1565       Alexandra                    Little Portugal
# 1          22795  Kathie & Larry  Waterfront Communities-The Island
# 2         113345           Adela  Waterfront Communities-The Island
# 3         118124           Brent                    South Riverdale
# 4          22795  Kathie & Larry  Waterfront Communities-The Island
# ...          ...             ...                                ...
# 48450  225740531      Toluwalase                        Fredericton
# 48454  464549197         Pradeep                            Moncton
# 48455  261453551           David                        Fredericton
# 48471  484541508           Ahmed                            Moncton
# 48484  133036673           Kamil                            Moncton
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      43.645900 -79.424230  Entire home/apt    NaN              28
# 1      43.640800 -79.376730     Private room  100.0             180
# 2      43.646080 -79.390320  Entire home/apt  145.0              28
# 3      43.668840 -79.327250  Entire home/apt   75.0              90
# 4      43.640150 -79.376250  Entire home/apt  134.0             180
# ...          ...        ...              ...    ...             ...
# 48450  45.955262 -66.694779  Entire home/apt   80.0               1
# 48454  46.118079 -64.836858  Entire home/apt  170.0               2
# 48455  45.948270 -66.652299  Entire home/apt  125.0               1
# 48471  46.092539 -64.783363  Entire home/apt  400.0               1
# 48484  46.104682 -64.828553  Entire home/apt   89.0               2
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      6  2017-08-07               0.06
# 1                    169  2013-08-27               0.96
# 2                     42  2023-09-01               0.27
# 3                     28  2023-08-31               0.17
# 4                      1  2010-08-11               0.01
# ...                  ...         ...                ...
# 48450                  3  2023-12-23               3.00
# 48454                  1  2023-12-26               1.00
# 48455                  2  2023-12-16               2.00
# 48471                  2  2023-12-18               2.00
# 48484                  1  2023-12-17               1.00
#
#        calculated_host_listings_count  availability_365  \
# 0                                   1                 0
# 1                                   2                 0
# 2                                   5                77
# 3                                   1               215
# 4                                   2                 0
# ...                               ...               ...
# 48450                               2               266
# 48454                               1               127
# 48455                               1                78
# 48471                               1               270
# 48484                               1               172
#
#        number_of_reviews_ltm license           city  \
# 0                          0     NaN        Toronto
# 1                          0     NaN        Toronto
# 2                          2     NaN        Toronto
# 3                          1     NaN        Toronto
# 4                          0     NaN        Toronto
# ...                      ...     ...            ...
# 48450                      3     NaN  New Brunswick
# 48454                      1     NaN  New Brunswick
# 48455                      2     NaN  New Brunswick
# 48471                      2     NaN  New Brunswick
# 48484                      1     NaN  New Brunswick
#
#                                                    url rating
# 0                     https://www.airbnb.ca/rooms/1419    5.0
# 1                     https://www.airbnb.ca/rooms/8077   4.84
# 2                    https://www.airbnb.ca/rooms/26654   4.79
# 3                    https://www.airbnb.ca/rooms/27423   4.93
# 4                    https://www.airbnb.ca/rooms/30931    NaN
# ...                                                ...    ...
# 48450  https://www.airbnb.ca/rooms/1036526981236768174   4.33
# 48454  https://www.airbnb.ca/rooms/1038950558720815520    NaN
# 48455  https://www.airbnb.ca/rooms/1039043653457446523    NaN
# 48471  https://www.airbnb.ca/rooms/1042152682470956407    NaN
# 48484  https://www.airbnb.ca/rooms/1047108429010491595    NaN
#
# [38534 rows x 20 columns]

# %%
cities.to_csv("../data/processed/airbnb_data.csv", sep=",", index=False)

# %%
cities
# Out:
#                         id                                               name  \
# 0                     1419  Home in Toronto · ★5.0 · 5 bedrooms · 7 beds ·...
# 1                     8077  Rental unit in Toronto · ★4.84 · 1 bedroom · 1...
# 2                    26654  Condo in Toronto · ★4.79 · 1 bedroom · 2 beds ...
# 3                    27423  Rental unit in Toronto · ★4.93 · Studio · 1 be...
# 4                    30931  Rental unit in Toronto · 1 bedroom · 2 beds · ...
# ...                    ...                                                ...
# 48450  1036526981236768174  Rental unit in Fredericton · ★4.33 · 1 bedroom...
# 48454  1038950558720815520  Home in Moncton · ★New · 3 bedrooms · 3 beds ·...
# 48455  1039043653457446523  Rental unit in Fredericton · ★New · 2 bedrooms...
# 48471  1042152682470956407  Rental unit in Moncton · ★New · 1 bedroom · 2 ...
# 48484  1047108429010491595  Home in Moncton · ★New · 2 bedrooms · 2 beds ·...
#
#          host_id       host_name                      neighbourhood  \
# 0           1565       Alexandra                    Little Portugal
# 1          22795  Kathie & Larry  Waterfront Communities-The Island
# 2         113345           Adela  Waterfront Communities-The Island
# 3         118124           Brent                    South Riverdale
# 4          22795  Kathie & Larry  Waterfront Communities-The Island
# ...          ...             ...                                ...
# 48450  225740531      Toluwalase                        Fredericton
# 48454  464549197         Pradeep                            Moncton
# 48455  261453551           David                        Fredericton
# 48471  484541508           Ahmed                            Moncton
# 48484  133036673           Kamil                            Moncton
#
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      43.645900 -79.424230  Entire home/apt    NaN              28
# 1      43.640800 -79.376730     Private room  100.0             180
# 2      43.646080 -79.390320  Entire home/apt  145.0              28
# 3      43.668840 -79.327250  Entire home/apt   75.0              90
# 4      43.640150 -79.376250  Entire home/apt  134.0             180
# ...          ...        ...              ...    ...             ...
# 48450  45.955262 -66.694779  Entire home/apt   80.0               1
# 48454  46.118079 -64.836858  Entire home/apt  170.0               2
# 48455  45.948270 -66.652299  Entire home/apt  125.0               1
# 48471  46.092539 -64.783363  Entire home/apt  400.0               1
# 48484  46.104682 -64.828553  Entire home/apt   89.0               2
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      6  2017-08-07               0.06
# 1                    169  2013-08-27               0.96
# 2                     42  2023-09-01               0.27
# 3                     28  2023-08-31               0.17
# 4                      1  2010-08-11               0.01
# ...                  ...         ...                ...
# 48450                  3  2023-12-23               3.00
# 48454                  1  2023-12-26               1.00
# 48455                  2  2023-12-16               2.00
# 48471                  2  2023-12-18               2.00
# 48484                  1  2023-12-17               1.00
#
#        calculated_host_listings_count  availability_365  \
# 0                                   1                 0
# 1                                   2                 0
# 2                                   5                77
# 3                                   1               215
# 4                                   2                 0
# ...                               ...               ...
# 48450                               2               266
# 48454                               1               127
# 48455                               1                78
# 48471                               1               270
# 48484                               1               172
#
#        number_of_reviews_ltm license           city  \
# 0                          0     NaN        Toronto
# 1                          0     NaN        Toronto
# 2                          2     NaN        Toronto
# 3                          1     NaN        Toronto
# 4                          0     NaN        Toronto
# ...                      ...     ...            ...
# 48450                      3     NaN  New Brunswick
# 48454                      1     NaN  New Brunswick
# 48455                      2     NaN  New Brunswick
# 48471                      2     NaN  New Brunswick
# 48484                      1     NaN  New Brunswick
#
#                                                    url rating
# 0                     https://www.airbnb.ca/rooms/1419    5.0
# 1                     https://www.airbnb.ca/rooms/8077   4.84
# 2                    https://www.airbnb.ca/rooms/26654   4.79
# 3                    https://www.airbnb.ca/rooms/27423   4.93
# 4                    https://www.airbnb.ca/rooms/30931    NaN
# ...                                                ...    ...
# 48450  https://www.airbnb.ca/rooms/1036526981236768174   4.33
# 48454  https://www.airbnb.ca/rooms/1038950558720815520    NaN
# 48455  https://www.airbnb.ca/rooms/1039043653457446523    NaN
# 48471  https://www.airbnb.ca/rooms/1042152682470956407    NaN
# 48484  https://www.airbnb.ca/rooms/1047108429010491595    NaN
#
# [38534 rows x 20 columns]
