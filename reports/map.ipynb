# %%
import pandas as pd
listings=pd.read_csv("../data/processed/airbnb_data.csv")
listings.head()
# Out:
#       id                                               name  host_id  \
# 0   1419  Home in Toronto · ★5.0 · 5 bedrooms · 7 beds ·...     1565
# 1   8077  Rental unit in Toronto · ★4.84 · 1 bedroom · 1...    22795
# 2  26654  Condo in Toronto · ★4.79 · 1 bedroom · 2 beds ...   113345
# 3  27423  Rental unit in Toronto · ★4.93 · Studio · 1 be...   118124
# 4  30931  Rental unit in Toronto · 1 bedroom · 2 beds · ...    22795
#
#         host_name                      neighbourhood  latitude  longitude  \
# 0       Alexandra                    Little Portugal  43.64590  -79.42423
# 1  Kathie & Larry  Waterfront Communities-The Island  43.64080  -79.37673
# 2           Adela  Waterfront Communities-The Island  43.64608  -79.39032
# 3           Brent                    South Riverdale  43.66884  -79.32725
# 4  Kathie & Larry  Waterfront Communities-The Island  43.64015  -79.37625
#
#          room_type  price  minimum_nights  ...  last_review reviews_per_month  \
# 0  Entire home/apt    NaN              28  ...   2017-08-07              0.06
# 1     Private room  100.0             180  ...   2013-08-27              0.96
# 2  Entire home/apt  145.0              28  ...   2023-09-01              0.27
# 3  Entire home/apt   75.0              90  ...   2023-08-31              0.17
# 4  Entire home/apt  134.0             180  ...   2010-08-11              0.01
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               1                 0                      0
# 1                               2                 0                      0
# 2                               5                77                      2
# 3                               1               215                      1
# 4                               2                 0                      0
#
#    license     city                                url  \
# 0      NaN  Toronto   https://www.airbnb.ca/rooms/1419
# 1      NaN  Toronto   https://www.airbnb.ca/rooms/8077
# 2      NaN  Toronto  https://www.airbnb.ca/rooms/26654
# 3      NaN  Toronto  https://www.airbnb.ca/rooms/27423
# 4      NaN  Toronto  https://www.airbnb.ca/rooms/30931
#
#                                   host url rating
# 0    https://www.airbnb.ca/users/show/1565   5.00
# 1   https://www.airbnb.ca/users/show/22795   4.84
# 2  https://www.airbnb.ca/users/show/113345   4.79
# 3  https://www.airbnb.ca/users/show/118124   4.93
# 4   https://www.airbnb.ca/users/show/22795    NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# #dropdown and listing numbers

# %%
city=listings['city'].unique().tolist()
city
# Out:
# ['Toronto',
#  'Vancouver',
#  'Quebec City',
#  'Victoria',
#  'Winnipeg',
#  'Montreal',
#  'New Brunswick']

# %%
neighbourhoods=listings.loc[listings['city']=='Vancouver', 'neighbourhood'].unique().tolist()

# %%
[{'label': neighbourhood, 'value': neighbourhood} for neighbourhood in neighbourhoods]
# Out:
# [{'label': 'Riley Park', 'value': 'Riley Park'},
#  {'label': 'Downtown', 'value': 'Downtown'},
#  {'label': 'Kensington-Cedar Cottage', 'value': 'Kensington-Cedar Cottage'},
#  {'label': 'Hastings-Sunrise', 'value': 'Hastings-Sunrise'},
#  {'label': 'Grandview-Woodland', 'value': 'Grandview-Woodland'},
#  {'label': 'Mount Pleasant', 'value': 'Mount Pleasant'},
#  {'label': 'West End', 'value': 'West End'},
#  {'label': 'Renfrew-Collingwood', 'value': 'Renfrew-Collingwood'},
#  {'label': 'Kitsilano', 'value': 'Kitsilano'},
#  {'label': 'Downtown Eastside', 'value': 'Downtown Eastside'},
#  {'label': 'Arbutus Ridge', 'value': 'Arbutus Ridge'},
#  {'label': 'Killarney', 'value': 'Killarney'},
#  {'label': 'South Cambie', 'value': 'South Cambie'},
#  {'label': 'Fairview', 'value': 'Fairview'},
#  {'label': 'Dunbar Southlands', 'value': 'Dunbar Southlands'},
#  {'label': 'Strathcona', 'value': 'Strathcona'},
#  {'label': 'West Point Grey', 'value': 'West Point Grey'},
#  {'label': 'Shaughnessy', 'value': 'Shaughnessy'},
#  {'label': 'Kerrisdale', 'value': 'Kerrisdale'},
#  {'label': 'Sunset', 'value': 'Sunset'},
#  {'label': 'Victoria-Fraserview', 'value': 'Victoria-Fraserview'},
#  {'label': 'Marpole', 'value': 'Marpole'},
#  {'label': 'Oakridge', 'value': 'Oakridge'}]

# %%
listings.groupby(['city', 'neighbourhood'])['id'].count()
# Out:
# city      neighbourhood
# Montreal  Ahuntsic-Cartierville        184
#           Anjou                         32
#           Baie-d'Urfé                    4
#           Beaconsfield                  21
#           Côte-Saint-Luc                12
#                                       ...
# Winnipeg  St. James                     85
#           St. Norbert - Seine River     91
#           St. Vital                    137
#           Transcona                     71
#           Waverley West                230
# Name: id, Length: 408, dtype: int64

# %%
number=listings.groupby(['city', 'neighbourhood'])['id'].count()
df=number.loc['Vancouver', ].reset_index().rename(columns={'id':'count'})

# %%
import altair as alt
alt.Chart(df, title='Number of Listings').mark_bar().encode(
    x=alt.X('count', title='Total Number'),
    y=alt.Y('neighbourhood', sort='x', title='Neighbourhood'),
    tooltip='count'
).interactive()
# Out:
# /Users/yujinxin/miniconda3/lib/python3.11/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %%
listings
# Out:
#                         id                                               name  \
# 0                     1419  Home in Toronto · ★5.0 · 5 bedrooms · 7 beds ·...
# 1                     8077  Rental unit in Toronto · ★4.84 · 1 bedroom · 1...
# 2                    26654  Condo in Toronto · ★4.79 · 1 bedroom · 2 beds ...
# 3                    27423  Rental unit in Toronto · ★4.93 · Studio · 1 be...
# 4                    30931  Rental unit in Toronto · 1 bedroom · 2 beds · ...
# ...                    ...                                                ...
# 38529  1036526981236768174  Rental unit in Fredericton · ★4.33 · 1 bedroom...
# 38530  1038950558720815520  Home in Moncton · ★New · 3 bedrooms · 3 beds ·...
# 38531  1039043653457446523  Rental unit in Fredericton · ★New · 2 bedrooms...
# 38532  1042152682470956407  Rental unit in Moncton · ★New · 1 bedroom · 2 ...
# 38533  1047108429010491595  Home in Moncton · ★New · 2 bedrooms · 2 beds ·...
#
#          host_id       host_name                      neighbourhood  \
# 0           1565       Alexandra                    Little Portugal
# 1          22795  Kathie & Larry  Waterfront Communities-The Island
# 2         113345           Adela  Waterfront Communities-The Island
# 3         118124           Brent                    South Riverdale
# 4          22795  Kathie & Larry  Waterfront Communities-The Island
# ...          ...             ...                                ...
# 38529  225740531      Toluwalase                        Fredericton
# 38530  464549197         Pradeep                            Moncton
# 38531  261453551           David                        Fredericton
# 38532  484541508           Ahmed                            Moncton
# 38533  133036673           Kamil                            Moncton
#
#         latitude  longitude        room_type  price  minimum_nights  ...  \
# 0      43.645900 -79.424230  Entire home/apt    NaN              28  ...
# 1      43.640800 -79.376730     Private room  100.0             180  ...
# 2      43.646080 -79.390320  Entire home/apt  145.0              28  ...
# 3      43.668840 -79.327250  Entire home/apt   75.0              90  ...
# 4      43.640150 -79.376250  Entire home/apt  134.0             180  ...
# ...          ...        ...              ...    ...             ...  ...
# 38529  45.955262 -66.694779  Entire home/apt   80.0               1  ...
# 38530  46.118079 -64.836858  Entire home/apt  170.0               2  ...
# 38531  45.948270 -66.652299  Entire home/apt  125.0               1  ...
# 38532  46.092539 -64.783363  Entire home/apt  400.0               1  ...
# 38533  46.104682 -64.828553  Entire home/apt   89.0               2  ...
#
#        last_review reviews_per_month  calculated_host_listings_count  \
# 0       2017-08-07              0.06                               1
# 1       2013-08-27              0.96                               2
# 2       2023-09-01              0.27                               5
# 3       2023-08-31              0.17                               1
# 4       2010-08-11              0.01                               2
# ...            ...               ...                             ...
# 38529   2023-12-23              3.00                               2
# 38530   2023-12-26              1.00                               1
# 38531   2023-12-16              2.00                               1
# 38532   2023-12-18              2.00                               1
# 38533   2023-12-17              1.00                               1
#
#        availability_365  number_of_reviews_ltm  license           city  \
# 0                     0                      0      NaN        Toronto
# 1                     0                      0      NaN        Toronto
# 2                    77                      2      NaN        Toronto
# 3                   215                      1      NaN        Toronto
# 4                     0                      0      NaN        Toronto
# ...                 ...                    ...      ...            ...
# 38529               266                      3      NaN  New Brunswick
# 38530               127                      1      NaN  New Brunswick
# 38531                78                      2      NaN  New Brunswick
# 38532               270                      2      NaN  New Brunswick
# 38533               172                      1      NaN  New Brunswick
#
#                                                    url  \
# 0                     https://www.airbnb.ca/rooms/1419
# 1                     https://www.airbnb.ca/rooms/8077
# 2                    https://www.airbnb.ca/rooms/26654
# 3                    https://www.airbnb.ca/rooms/27423
# 4                    https://www.airbnb.ca/rooms/30931
# ...                                                ...
# 38529  https://www.airbnb.ca/rooms/1036526981236768174
# 38530  https://www.airbnb.ca/rooms/1038950558720815520
# 38531  https://www.airbnb.ca/rooms/1039043653457446523
# 38532  https://www.airbnb.ca/rooms/1042152682470956407
# 38533  https://www.airbnb.ca/rooms/1047108429010491595
#
#                                          host url rating
# 0           https://www.airbnb.ca/users/show/1565   5.00
# 1          https://www.airbnb.ca/users/show/22795   4.84
# 2         https://www.airbnb.ca/users/show/113345   4.79
# 3         https://www.airbnb.ca/users/show/118124   4.93
# 4          https://www.airbnb.ca/users/show/22795    NaN
# ...                                           ...    ...
# 38529  https://www.airbnb.ca/users/show/225740531   4.33
# 38530  https://www.airbnb.ca/users/show/464549197    NaN
# 38531  https://www.airbnb.ca/users/show/261453551    NaN
# 38532  https://www.airbnb.ca/users/show/484541508    NaN
# 38533  https://www.airbnb.ca/users/show/133036673    NaN
#
# [38534 rows x 21 columns]

# %%
idx=(listings['city']=='Vancouver')&(listings['neighbourhood']=='Downtown')
price=listings.loc[idx, ]
price.shape[0]
# Out:
# 1418

# %%
idx=listings['city']=='Vancouver'
price=listings.loc[idx, 'price']
price.max()
# Out:
# 28650.0

# %%
lower_bound=100
upper_bound=1000

# %%
idx=(listings['city']=='Vancouver')&(listings['neighbourhood']=='Downtown')&(listings['price'].between(lower_bound, upper_bound) )
listings.loc[idx, 'id']
# Out:
# 15130                  13358
# 15139                  19621
# 15144                  26047
# 15147                  42645
# 15150                  73841
#                 ...
# 20664    1026854357228172802
# 20666    1027071906889057735
# 20671    1032625040159335264
# 20677    1035078706077601688
# 20679    1038818138105122048
# Name: id, Length: 1176, dtype: int64

# %%
listings.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm', 'license', 'city', 'url', 'host url',
#        'rating'],
#       dtype='object')

# %% [markdown]
# map

# %%
listings.loc[listings['city']=='Vancouver', ['latitude']]
# Out:
#         latitude
# 15128  49.247730
# 15129  49.254890
# 15130  49.281174
# 15131  49.256220
# 15132  49.249220
# ...          ...
# 20675  49.252823
# 20676  49.236970
# 20677  49.276704
# 20678  49.282975
# 20679  49.280007
#
# [5552 rows x 1 columns]

# %%
listings.groupby(['city'])[['longitude', 'latitude']].count()
# Out:
#                longitude  latitude
# city
# Montreal            6930      6930
# New Brunswick       3381      3381
# Quebec City         1908      1908
# Toronto            15128     15128
# Vancouver           5552      5552
# Victoria            4039      4039
# Winnipeg            1596      1596
